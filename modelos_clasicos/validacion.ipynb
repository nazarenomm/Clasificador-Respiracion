# %%
import joblib
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import librosa

from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, RocCurveDisplay, precision_recall_curve

from transformers import Resampler, BandPassFilter, MelSpectrogramTransformer, SpectrogramPadder, FlattenTransformer, FeatureExtractor, Normalizer

from config import N_MELS

# %%
def show_precision_recall_curve(y_true, y_proba, punto_corte=0.5):
    prec, rec, thr = precision_recall_curve(y_true, y_proba)

    plt.plot(thr, rec[:-1], label='recall')
    plt.plot(thr, prec[:-1], label='precision')
    plt.xlabel('Punto de corte')
    plt.vlines(punto_corte, 0, 1, colors='red', linestyles='dashed', label='corte')
    plt.grid()
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.legend()
    plt.show()

def show_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Matriz de Confusión');

def load_image_dataset_pil(img_dir, to_gray=True, flatten=False, target_size=None):
    df = pd.read_csv(os.path.join(img_dir, 'labels.csv'))
    X, y = [], []
    for _, row in df.iterrows():
        path = os.path.join(img_dir, row['filename'])
        img = Image.open(path)
        
        if to_gray:
            img = img.convert('L')  # convierte a escala de grises (1 canal)
        
        if target_size:
            img = img.resize(target_size, Image.BICUBIC)
        
        img = np.array(img, dtype=np.float32)
        
        if flatten:
            img = img.flatten()
        
        X.append(img)
        y.append(row['label'])
    
    return np.array(X), np.array(y)

# %% [markdown]
# ## Pipelines
#
# Se pueden probar la sustración espectral o wavelet denoising

# %%
pipeline_melspec = Pipeline([
    ('resampler', Resampler()),
    ('bandpass', BandPassFilter()),
    ('normalizer', Normalizer()),  ### Por la pipeline del dataset
    ('melspec', MelSpectrogramTransformer()),
    ('padder', SpectrogramPadder()),
    ('flatten', FlattenTransformer())
])

pipeline_features = Pipeline([
    ('resampler', Resampler()),
    ('bandpass', BandPassFilter()),
    ('normalizer', Normalizer()),  ### Por la pipeline del dataset
    ('feature_extractor', FeatureExtractor())
])

# %% [markdown]
# ## Audios de validación

# %% [markdown]
# ### propios

# %%
path = './audios_propios/ciclos_energy_based'
files = os.listdir(path)

# %%
paths = [os.path.join(path, f) for f in files]

# %%
X_propios_melspec = pipeline_melspec.fit_transform(paths)

# %%
X_propios_features = pipeline_features.fit_transform(paths)

# %%
path_img = './audios_propios/ciclos_energy_based_mel_images'

# %%
X_propios_img = []
for f in files:
    img_path = os.path.join(path_img, f.replace('.wav', '.png'))
    img = Image.open(img_path).convert('L')
    img = img.resize((256, N_MELS), Image.BICUBIC)
    img = np.array(img, dtype=np.float32)
    img = img.flatten()
    X_propios_img.append(np.array(img))

# %% [markdown]
# ### coswara

# %% [markdown]
# Hay que segmentarlos!!!

# %%
dataset = 'ciclos_hl256_peak_t_aug_padmin_wd'

# %% [markdown]
# # Espectrogramas

# %% [markdown]
# ## Random Forest

# %%
test_data = np.load(f'./dataset/{dataset}/test_melspectrogram.npz')
X_test = test_data['X']
y_test = test_data['y']

# %%
melspec_rf = joblib.load(f'./modelos/{dataset}/melspec_rf.pkl')

# %%
importances = melspec_rf.feature_importances_

n_mels = N_MELS
n_frames = importances.shape[0] // n_mels

importance_img = importances.reshape((n_mels, n_frames))

plt.figure(figsize=(10, 6))
sns.heatmap(
    importance_img,
    cmap='viridis',
    cbar_kws={'label': 'Importancia del feature'},
)
plt.xlabel("Tiempo (frames)")
plt.ylabel("Banda mel")
plt.title("Mapa de importancia de features del Random Forest")
plt.show()

# %%
y_pred = melspec_rf.predict(X_test)
y_pred_proba = melspec_rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61      1452
#            1       0.59      0.52      0.55      1398
#
#     accuracy                           0.58      2850
#    macro avg       0.59      0.58      0.58      2850
# weighted avg       0.59      0.58      0.58      2850

# %%
RocCurveDisplay.from_predictions(y_test, y_pred_proba);

# %%
show_confusion_matrix(y_test, y_pred)

# %%
show_precision_recall_curve(y_test, y_pred_proba, punto_corte=0.5)

# %%
probas_propios = melspec_rf.predict_proba(X_propios_melspec)[:, 1]
df_probas = pd.DataFrame({
    'file': files,
    'proba': probas_propios
})
sns.histplot(df_probas, x='proba', bins=20);

# %%
df_probas
# Out:
#                         file     proba
# 0   respiracion1_ciclo_1.wav  0.488898
# 1   respiracion1_ciclo_2.wav  0.320032
# 2   respiracion1_ciclo_3.wav  0.604077
# 3   respiracion1_ciclo_4.wav  0.372101
# 4   respiracion1_ciclo_5.wav  0.504218
# 5   respiracion1_ciclo_6.wav  0.412933
# 6   respiracion1_ciclo_7.wav  0.593531
# 7   respiracion2_ciclo_1.wav  0.461139
# 8   respiracion2_ciclo_2.wav  0.540031
# 9   respiracion2_ciclo_3.wav  0.539820
# 10  respiracion2_ciclo_4.wav  0.403312
# 11  respiracion2_ciclo_5.wav  0.488615
# 12  respiracion2_ciclo_6.wav  0.341645
# 13  respiracion3_ciclo_1.wav  0.453367
# 14  respiracion3_ciclo_2.wav  0.495233
# 15  respiracion3_ciclo_3.wav  0.575976
# 16  respiracion3_ciclo_4.wav  0.513070
# 17  respiracion3_ciclo_5.wav  0.513534
# 18  respiracion3_ciclo_6.wav  0.502640
# 19  respiracion4_ciclo_1.wav  0.455982
# 20  respiracion4_ciclo_2.wav  0.505999
# 21  respiracion4_ciclo_3.wav  0.513179
# 22  respiracion4_ciclo_4.wav  0.565741
# 23  respiracion4_ciclo_5.wav  0.569967
# 24  respiracion4_ciclo_6.wav  0.382784
# 25  respiracion4_ciclo_7.wav  0.506244
# 26  respiracion5_ciclo_1.wav  0.525346
# 27  respiracion5_ciclo_2.wav  0.597237
# 28  respiracion5_ciclo_3.wav  0.548959
# 29  respiracion5_ciclo_4.wav  0.504597
# 30  respiracion5_ciclo_5.wav  0.545035
# 31  respiracion5_ciclo_6.wav  0.254211
# 32  respiracion6_ciclo_1.wav  0.468866
# 33  respiracion6_ciclo_2.wav  0.411389
# 34  respiracion6_ciclo_3.wav  0.532261
# 35  respiracion6_ciclo_4.wav  0.416687
# 36  respiracion6_ciclo_5.wav  0.418167
# 37  respiracion6_ciclo_6.wav  0.255658
# 38  respiracion6_ciclo_7.wav  0.265489
# 39  respiracion7_ciclo_1.wav  0.559531
# 40  respiracion7_ciclo_2.wav  0.444227
# 41  respiracion7_ciclo_3.wav  0.480609
# 42  respiracion7_ciclo_4.wav  0.459810
# 43  respiracion7_ciclo_5.wav  0.310102
# 44  respiracion8_ciclo_1.wav  0.499451
# 45  respiracion8_ciclo_2.wav  0.495481
# 46  respiracion8_ciclo_3.wav  0.499163
# 47  respiracion8_ciclo_4.wav  0.540832
# 48  respiracion8_ciclo_5.wav  0.299027

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
melspec_gbc = joblib.load(f'./modelos/{dataset}/melspec_gbc.pkl')

# %%
importances = melspec_gbc.feature_importances_

n_mels = N_MELS
n_frames = importances.shape[0] // n_mels

importance_img = importances.reshape((n_mels, n_frames))

plt.figure(figsize=(10, 6))
sns.heatmap(
    importance_img,
    cmap="viridis",
    cbar_kws={'label': 'Importancia del feature'},
)
plt.xlabel("Tiempo (frames)")
plt.ylabel("Banda mel")
plt.title("Mapa de importancia de features del Gradient Boosting Classifier")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 importances = melspec_gbc.feature_importances_
#       3 n_mels = N_MELS
#       4 n_frames = importances.shape[0] // n_mels
#
# AttributeError: 'HistGradientBoostingClassifier' object has no attribute 'feature_importances_'

# %%
y_pred = melspec_gbc.predict(X_test)
y_pred_proba = melspec_gbc.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.65      0.62      1452
#            1       0.60      0.54      0.57      1398
#
#     accuracy                           0.60      2850
#    macro avg       0.60      0.60      0.60      2850
# weighted avg       0.60      0.60      0.60      2850

# %%
RocCurveDisplay.from_predictions(y_test, y_pred_proba);

# %%
show_confusion_matrix(y_test, y_pred)

# %%
show_precision_recall_curve(y_test, y_pred_proba, punto_corte=0.5)

# %%
probas_propios = melspec_gbc.predict_proba(X_propios_melspec)[:, 1]
df_probas = pd.DataFrame({
    'file': files,
    'proba': probas_propios
})
sns.histplot(df_probas, x='proba', bins=20);

# %%
df_probas
# Out:
#                         file     proba
# 0   respiracion1_ciclo_1.wav  0.645997
# 1   respiracion1_ciclo_2.wav  0.267474
# 2   respiracion1_ciclo_3.wav  0.681026
# 3   respiracion1_ciclo_4.wav  0.086285
# 4   respiracion1_ciclo_5.wav  0.620084
# 5   respiracion1_ciclo_6.wav  0.488187
# 6   respiracion1_ciclo_7.wav  0.795854
# 7   respiracion2_ciclo_1.wav  0.576457
# 8   respiracion2_ciclo_2.wav  0.757628
# 9   respiracion2_ciclo_3.wav  0.650807
# 10  respiracion2_ciclo_4.wav  0.684222
# 11  respiracion2_ciclo_5.wav  0.724906
# 12  respiracion2_ciclo_6.wav  0.296779
# 13  respiracion3_ciclo_1.wav  0.657641
# 14  respiracion3_ciclo_2.wav  0.568547
# 15  respiracion3_ciclo_3.wav  0.413914
# 16  respiracion3_ciclo_4.wav  0.516279
# 17  respiracion3_ciclo_5.wav  0.362752
# 18  respiracion3_ciclo_6.wav  0.508218
# 19  respiracion4_ciclo_1.wav  0.709240
# 20  respiracion4_ciclo_2.wav  0.275502
# 21  respiracion4_ciclo_3.wav  0.575022
# 22  respiracion4_ciclo_4.wav  0.771151
# 23  respiracion4_ciclo_5.wav  0.538389
# 24  respiracion4_ciclo_6.wav  0.458042
# 25  respiracion4_ciclo_7.wav  0.793229
# 26  respiracion5_ciclo_1.wav  0.567331
# 27  respiracion5_ciclo_2.wav  0.630841
# 28  respiracion5_ciclo_3.wav  0.804746
# 29  respiracion5_ciclo_4.wav  0.668795
# 30  respiracion5_ciclo_5.wav  0.667092
# 31  respiracion5_ciclo_6.wav  0.104033
# 32  respiracion6_ciclo_1.wav  0.655444
# 33  respiracion6_ciclo_2.wav  0.457280
# 34  respiracion6_ciclo_3.wav  0.409772
# 35  respiracion6_ciclo_4.wav  0.228133
# 36  respiracion6_ciclo_5.wav  0.404465
# 37  respiracion6_ciclo_6.wav  0.114726
# 38  respiracion6_ciclo_7.wav  0.118982
# 39  respiracion7_ciclo_1.wav  0.807790
# 40  respiracion7_ciclo_2.wav  0.281293
# 41  respiracion7_ciclo_3.wav  0.630396
# 42  respiracion7_ciclo_4.wav  0.824352
# 43  respiracion7_ciclo_5.wav  0.282085
# 44  respiracion8_ciclo_1.wav  0.781400
# 45  respiracion8_ciclo_2.wav  0.624160
# 46  respiracion8_ciclo_3.wav  0.778056
# 47  respiracion8_ciclo_4.wav  0.644384
# 48  respiracion8_ciclo_5.wav  0.147653

# %% [markdown]
# # Features

# %% [markdown]
# ## Random Forest

# %%
test_data = np.load(f'./dataset/{dataset}/test_features.npz')
X_test = test_data['X']
y_test = test_data['y']

# %%
feat_rf = joblib.load(f'./modelos/{dataset}/features_rf.pkl')

# %%
importances = feat_rf.feature_importances_
columns = ['mfcc_' + str(i) for i in range(1, 41)] + ['zcr', 'energy', 'spectral_centroid', 'spectral_rolloff', 'ber', 'spectral_flatness']

importance_df = pd.DataFrame({
    'feature': columns,
    'importance': importances
})
plt.figure(figsize=(6, 8))
sns.barplot(data=importance_df, x='importance', y='feature')
plt.tight_layout();

# %%
y_pred = feat_rf.predict(X_test)
y_pred_proba = feat_rf.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.86      0.70      1452
#            1       0.72      0.36      0.48      1398
#
#     accuracy                           0.62      2850
#    macro avg       0.65      0.61      0.59      2850
# weighted avg       0.65      0.62      0.59      2850

# %%
RocCurveDisplay.from_predictions(y_test, y_pred_proba);

# %%
show_confusion_matrix(y_test, y_pred)

# %%
show_precision_recall_curve(y_test, y_pred_proba, punto_corte=0.5)

# %%
probas_propios = feat_rf.predict_proba(X_propios_features)[:, 1]
df_probas = pd.DataFrame({
    'file': files,
    'proba': probas_propios
})

# %%
sns.histplot(df_probas, x='proba', bins=20);

# %%
df_probas
# Out:
#                         file     proba
# 0   respiracion1_ciclo_1.wav  0.541474
# 1   respiracion1_ciclo_2.wav  0.402633
# 2   respiracion1_ciclo_3.wav  0.553971
# 3   respiracion1_ciclo_4.wav  0.475598
# 4   respiracion1_ciclo_5.wav  0.427045
# 5   respiracion1_ciclo_6.wav  0.399590
# 6   respiracion1_ciclo_7.wav  0.389163
# 7   respiracion2_ciclo_1.wav  0.487986
# 8   respiracion2_ciclo_2.wav  0.535744
# 9   respiracion2_ciclo_3.wav  0.474171
# 10  respiracion2_ciclo_4.wav  0.484539
# 11  respiracion2_ciclo_5.wav  0.451833
# 12  respiracion2_ciclo_6.wav  0.479963
# 13  respiracion3_ciclo_1.wav  0.587491
# 14  respiracion3_ciclo_2.wav  0.504449
# 15  respiracion3_ciclo_3.wav  0.466660
# 16  respiracion3_ciclo_4.wav  0.534086
# 17  respiracion3_ciclo_5.wav  0.501133
# 18  respiracion3_ciclo_6.wav  0.498194
# 19  respiracion4_ciclo_1.wav  0.621269
# 20  respiracion4_ciclo_2.wav  0.614294
# 21  respiracion4_ciclo_3.wav  0.550484
# 22  respiracion4_ciclo_4.wav  0.574652
# 23  respiracion4_ciclo_5.wav  0.480876
# 24  respiracion4_ciclo_6.wav  0.528570
# 25  respiracion4_ciclo_7.wav  0.479915
# 26  respiracion5_ciclo_1.wav  0.412662
# 27  respiracion5_ciclo_2.wav  0.443009
# 28  respiracion5_ciclo_3.wav  0.405957
# 29  respiracion5_ciclo_4.wav  0.404626
# 30  respiracion5_ciclo_5.wav  0.446885
# 31  respiracion5_ciclo_6.wav  0.408305
# 32  respiracion6_ciclo_1.wav  0.449375
# 33  respiracion6_ciclo_2.wav  0.435212
# 34  respiracion6_ciclo_3.wav  0.463850
# 35  respiracion6_ciclo_4.wav  0.469985
# 36  respiracion6_ciclo_5.wav  0.478234
# 37  respiracion6_ciclo_6.wav  0.426455
# 38  respiracion6_ciclo_7.wav  0.430851
# 39  respiracion7_ciclo_1.wav  0.568530
# 40  respiracion7_ciclo_2.wav  0.542336
# 41  respiracion7_ciclo_3.wav  0.475846
# 42  respiracion7_ciclo_4.wav  0.507917
# 43  respiracion7_ciclo_5.wav  0.571461
# 44  respiracion8_ciclo_1.wav  0.571377
# 45  respiracion8_ciclo_2.wav  0.490998
# 46  respiracion8_ciclo_3.wav  0.508748
# 47  respiracion8_ciclo_4.wav  0.502727
# 48  respiracion8_ciclo_5.wav  0.549329

# %% [markdown]
# ## Gradient Boosting

# %%
feat_gbc = joblib.load(f'./modelos/{dataset}/features_gbc.pkl')

# %%
importances = feat_gbc.feature_importances_
columns = ['mfcc_' + str(i) for i in range(1, 41)] + ['zcr', 'energy', 'spectral_centroid', 'spectral_rolloff', 'ber', 'spectral_flatness']

importance_df = pd.DataFrame({
    'feature': columns,
    'importance': importances
})
plt.figure(figsize=(6, 8))
sns.barplot(data=importance_df, x='importance', y='feature')
plt.tight_layout();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 importances = feat_gbc.feature_importances_
#       2 columns = ['mfcc_' + str(i) for i in range(1, 41)] + ['zcr', 'energy', 'spectral_centroid', 'spectral_rolloff', 'ber', 'spectral_flatness']
#       4 importance_df = pd.DataFrame({
#       5     'feature': columns,
#       6     'importance': importances
#       7 })
#
# AttributeError: 'HistGradientBoostingClassifier' object has no attribute 'feature_importances_'

# %%
y_pred = feat_gbc.predict(X_test)
y_pred_proba = feat_gbc.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.85      0.69      1452
#            1       0.70      0.37      0.48      1398
#
#     accuracy                           0.61      2850
#    macro avg       0.64      0.61      0.59      2850
# weighted avg       0.64      0.61      0.59      2850

# %%
RocCurveDisplay.from_predictions(y_test, y_pred_proba);

# %%
show_confusion_matrix(y_test, y_pred)

# %%
show_precision_recall_curve(y_test, y_pred_proba, punto_corte=0.5)

# %%
probas_propios = feat_gbc.predict_proba(X_propios_features)[:, 1]
df_probas = pd.DataFrame({
    'file': files,
    'proba': probas_propios
})

# %%
sns.histplot(df_probas, x='proba', bins=20);

# %%
df_probas
# Out:
#                         file     proba
# 0   respiracion1_ciclo_1.wav  0.648334
# 1   respiracion1_ciclo_2.wav  0.509357
# 2   respiracion1_ciclo_3.wav  0.536757
# 3   respiracion1_ciclo_4.wav  0.485283
# 4   respiracion1_ciclo_5.wav  0.176172
# 5   respiracion1_ciclo_6.wav  0.540869
# 6   respiracion1_ciclo_7.wav  0.146624
# 7   respiracion2_ciclo_1.wav  0.248939
# 8   respiracion2_ciclo_2.wav  0.497935
# 9   respiracion2_ciclo_3.wav  0.360141
# 10  respiracion2_ciclo_4.wav  0.376511
# 11  respiracion2_ciclo_5.wav  0.344559
# 12  respiracion2_ciclo_6.wav  0.224712
# 13  respiracion3_ciclo_1.wav  0.713308
# 14  respiracion3_ciclo_2.wav  0.537950
# 15  respiracion3_ciclo_3.wav  0.755449
# 16  respiracion3_ciclo_4.wav  0.584868
# 17  respiracion3_ciclo_5.wav  0.714947
# 18  respiracion3_ciclo_6.wav  0.697290
# 19  respiracion4_ciclo_1.wav  0.749130
# 20  respiracion4_ciclo_2.wav  0.656077
# 21  respiracion4_ciclo_3.wav  0.619201
# 22  respiracion4_ciclo_4.wav  0.453192
# 23  respiracion4_ciclo_5.wav  0.478497
# 24  respiracion4_ciclo_6.wav  0.517092
# 25  respiracion4_ciclo_7.wav  0.475822
# 26  respiracion5_ciclo_1.wav  0.360581
# 27  respiracion5_ciclo_2.wav  0.252744
# 28  respiracion5_ciclo_3.wav  0.239085
# 29  respiracion5_ciclo_4.wav  0.442383
# 30  respiracion5_ciclo_5.wav  0.449143
# 31  respiracion5_ciclo_6.wav  0.169083
# 32  respiracion6_ciclo_1.wav  0.342727
# 33  respiracion6_ciclo_2.wav  0.206497
# 34  respiracion6_ciclo_3.wav  0.281037
# 35  respiracion6_ciclo_4.wav  0.208762
# 36  respiracion6_ciclo_5.wav  0.457422
# 37  respiracion6_ciclo_6.wav  0.460928
# 38  respiracion6_ciclo_7.wav  0.190570
# 39  respiracion7_ciclo_1.wav  0.513259
# 40  respiracion7_ciclo_2.wav  0.592082
# 41  respiracion7_ciclo_3.wav  0.394677
# 42  respiracion7_ciclo_4.wav  0.486642
# 43  respiracion7_ciclo_5.wav  0.563951
# 44  respiracion8_ciclo_1.wav  0.367643
# 45  respiracion8_ciclo_2.wav  0.261114
# 46  respiracion8_ciclo_3.wav  0.535155
# 47  respiracion8_ciclo_4.wav  0.492306
# 48  respiracion8_ciclo_5.wav  0.792037

# %% [markdown]
# # Imagenes

# %%
test_dir = f'./dataset/{dataset}/mel_images/test'
X_test, y_test = load_image_dataset_pil(test_dir, to_gray=True, flatten=True, target_size=(256, N_MELS))

# %%
img_rf = joblib.load(f'./modelos/{dataset}/melspec_img_rf.pkl')

# %%
importances = img_rf.feature_importances_
importance_img = importances.reshape((256, N_MELS))

plt.figure(figsize=(10, 6))
sns.heatmap(
    importance_img,
    cmap='viridis',
    cbar_kws={'label': 'Importancia del feature'},
)
plt.title("Mapa de importancia de features del Random Forest")
plt.show()

# %%
y_pred = img_rf.predict(X_test)
y_pred_proba = img_rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68       663
#            1       0.66      0.71      0.69       633
#
#     accuracy                           0.68      1296
#    macro avg       0.68      0.68      0.68      1296
# weighted avg       0.68      0.68      0.68      1296

# %%
RocCurveDisplay.from_predictions(y_test, y_pred_proba);

# %%
show_confusion_matrix(y_test, y_pred)

# %%
show_precision_recall_curve(y_test, y_pred_proba, punto_corte=0.5)

# %%
probas_propios = img_rf.predict_proba(X_propios_img)[:, 1]
df_probas = pd.DataFrame({
    'file': files,
    'proba': probas_propios
})
sns.histplot(df_probas, x='proba', bins=20);

# %%
df_probas.sort_values(by='proba', ascending=False)
# Out:
#                         file     proba
# 23  respiracion4_ciclo_5.wav  0.629125
# 30  respiracion5_ciclo_5.wav  0.595693
# 20  respiracion4_ciclo_2.wav  0.578642
# 22  respiracion4_ciclo_4.wav  0.561887
# 39  respiracion7_ciclo_1.wav  0.543636
# 47  respiracion8_ciclo_4.wav  0.543442
# 44  respiracion8_ciclo_1.wav  0.538082
# 12  respiracion2_ciclo_6.wav  0.524330
# 36  respiracion6_ciclo_5.wav  0.515792
# 2   respiracion1_ciclo_3.wav  0.515358
# 0   respiracion1_ciclo_1.wav  0.513413
# 15  respiracion3_ciclo_3.wav  0.508666
# 24  respiracion4_ciclo_6.wav  0.500972
# 19  respiracion4_ciclo_1.wav  0.500928
# 6   respiracion1_ciclo_7.wav  0.500900
# 45  respiracion8_ciclo_2.wav  0.498247
# 26  respiracion5_ciclo_1.wav  0.496936
# 16  respiracion3_ciclo_4.wav  0.494435
# 25  respiracion4_ciclo_7.wav  0.494237
# 14  respiracion3_ciclo_2.wav  0.492257
# 42  respiracion7_ciclo_4.wav  0.491682
# 8   respiracion2_ciclo_2.wav  0.490733
# 17  respiracion3_ciclo_5.wav  0.490651
# 28  respiracion5_ciclo_3.wav  0.487353
# 9   respiracion2_ciclo_3.wav  0.486640
# 11  respiracion2_ciclo_5.wav  0.484858
# 40  respiracion7_ciclo_2.wav  0.483973
# 27  respiracion5_ciclo_2.wav  0.483803
# 18  respiracion3_ciclo_6.wav  0.478963
# 21  respiracion4_ciclo_3.wav  0.478839
# 4   respiracion1_ciclo_5.wav  0.478522
# 41  respiracion7_ciclo_3.wav  0.472851
# 46  respiracion8_ciclo_3.wav  0.458786
# 5   respiracion1_ciclo_6.wav  0.452310
# 13  respiracion3_ciclo_1.wav  0.451467
# 29  respiracion5_ciclo_4.wav  0.449907
# 7   respiracion2_ciclo_1.wav  0.447035
# 32  respiracion6_ciclo_1.wav  0.446536
# 34  respiracion6_ciclo_3.wav  0.437684
# 10  respiracion2_ciclo_4.wav  0.427541
# 48  respiracion8_ciclo_5.wav  0.424277
# 43  respiracion7_ciclo_5.wav  0.421782
# 33  respiracion6_ciclo_2.wav  0.411832
# 31  respiracion5_ciclo_6.wav  0.408658
# 35  respiracion6_ciclo_4.wav  0.405370
# 1   respiracion1_ciclo_2.wav  0.373431
# 3   respiracion1_ciclo_4.wav  0.357061
# 38  respiracion6_ciclo_7.wav  0.325561
# 37  respiracion6_ciclo_6.wav  0.322144
