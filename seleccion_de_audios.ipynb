# %% [markdown]
# Filtrar audios de duraciones muy altas
# Quedarnos con los del AKGC y Tc
# Ver como afecta el resampling con espectrogramas
# Ver espectrogramas de casos positivos para wheeze y/o crackles, para saber el rango la frecuencia importante
# Balancear metadata
# Separar en train y test, guardar
